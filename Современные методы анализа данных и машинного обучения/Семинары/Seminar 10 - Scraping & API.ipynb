# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2023-24 учебный год

# %% [markdown]
# # Семинар 10. Data Scraping. API

# %% [markdown]
# ## Раздел 1. Web Scraping. Data Parsing

# %% [markdown]
# Прежде чем перейти к обсуждению и практическому освоению такого процесса, как Data Scraping, необходимо для начала освежить в памяти основы языка разметки HTML, поскольку всё то, с чем нам предстоит дальше работать, будет иметь именно такую разметку и оформление.

# %% [markdown]
# ### Язык HTML
#
# HTML (HyperText Markup Language) – это язык разметки, используемый для представления веб-страниц в интернете (для тех, кто работал с текстовыми ячейками в юпитеровских ноутбуках – в них, например, тоже используется свой язык разметки, только попроще). Принимая во внимание, что HTML – это язык разметки, а не язык программирования (вопреки расхожему заблуждению), – получается, что любая html-страница – это, по сути, самый обычный текст, в котором просто отмечено, какие части представляют собой заголовок, абзац, какие – таблицу, картинку, ну и так далее. Кстати, правилом хорошего тона считается включать в html-код как раз таки только содержательные вещи – текст и разметку; все оформление и интерактив принято выносить в отдельные файлы.
#
# В целом, чтобы было понятнее, как это всё работает, поясним, что обычно за страницей в интернете кроется примерно следующее. На сервере лежит несколько папок. В одной папке лежат сами html-страницы с размеченным текстом. В другой – хранятся файлы *css* (*Cascading Style Sheets*), в которых заданы параметры оформления этих страниц (цвет заголовков, фона, меню, ширина рамочек вокруг текста и картинок и прочее). В третьей папке находятся файлы с кодом на *JavaScript*, которые отвечают за всевозможный интерактив: будь то всплывающий перевод слова при наведении курсора, увеличение картинки при просмотре, подсветка формы для заполнения, если формат даты неверный, и так далее. JavaScript ‒ тоже отдельный язык программирования, на котором пишется код, соответствующий интерактиву (кстати, несмотря на название, с Java он никак не связан).
#
# Все эти файлы чётко связаны между собой: к каждой html-странице с разметкой присоединены с помощью ссылок css-файл с оформлением и код javascript. Таким образом собирается воедино весь сайт.
#
# Иногда, впрочем, html-страницы создаются не по стандартам и в файле с текстом могут встретиться огромные куски, например отвечающие за оформление. Это, к сожалению, значительно затрудняет работу с ними (с такими сайтами мы ещё столкнемся в дальнейшем).

# %% [markdown]
# Сегодня мы с вами начнем разбирать веб-скрейпинг и дата-парсинг для html-файлов. Обычно два этих процесса связаны, просто парсинг – более узкое понятие. Веб-скрейпинг (*web scraping*) – это в целом процесс выгрузки данных с веб-страниц; а парсинг (*parsing*) – это выбор текста из файла с разметкой, например из xml или html, как у нас.
#
# Но прежде, чем разбирать, как осуществляется работа с html-файлами, давайте получше познакомимся с их структурой. Для этого параллельно с рассмотрением дальнейших ячеек ноутбука предлагаем зайти на сайт [w3schools.com](https://www.w3schools.com/Html/) и открыть раздел [Try it yourself](https://www.w3schools.com/Html/tryit.asp?filename=tryhtml_default). W3Schools – отличный учебный инструмент для создания html-файлов, и да, на сайте в целом много документации и тьюториалов по html, css и веб-дизайну вообще. Почитайте потом на досуге!

# %% [markdown]
# Но вернемся к структуре HTML-файлов. Для начала стоит упомянуть, что в HTML для разметки везде используются тэги – служебные слова в треугольных скобках `<>`. Тэги бывают двух видов: открывающие и закрывающие. Открывающие тэги выглядят так, как представлено выше, а закрывающие – почти так же, но начинаются с прямого слэша (`/`).
#
# Вся страница заключается в тэг `<html></html>`. В начале обычно указывается какая-то мета-информация: язык страницы, кодировка, метки, название и прочее. Здесь, правда, такого нет. "Тело" документа – собственно страница, которая отображается при просмотре, – заключается в тэг `<body></body>`.
#
# Для заголовков используются тэги с `h` (`h` – от *header*): тэги `<h1></h1>`  ‒ для заголовков первого уровня, тэг `<h2></h2>` – для заголовков второго уровня и так далее. В тэги `<p></p>` заключаются абзацы (`p` – от *paragraph*).

# %% [markdown]
# Приостановимся пока с теорией и приступим к созданию своей первой html-странички! Вначале внесем изменения в файл ‒ создадим страничку "о себе". Для этого можете скопировать код ниже и вставить его в поле в разделе *Try it Yourself*, а затем нажать кнопку *Run*.

# %%
<!DOCTYPE html>
<html>
<head>
<title>Page Title</title>
</head>
<body>

<h1>Моя первая html-страница</h1>
<h2>О себе</h2>
<p>Я учусь создавать html-страницы.</p>

</body>
</html>

# %% [markdown]
# Теперь добавим небольшую таблицу. Знания об устройстве таблиц нам понадобятся, потому что чаще всего при парсинге приходится «выцеплять» данные как раз из таблиц на html-страницах.
#
# Вся таблица заключается в тэги `<table></table>`. Далее таблица заполняется по строкам. Строка таблицы заключается в тэги `<tr></tr>` (от *table row*); затем идут ячейки таблицы ‒ они тоже имеют свои тэги. Если ячейка обычная ‒ то есть не является названием столбца или строки ‒ она окружена тэгом `<td></td>` (от *table*). Если же является ‒ тег будет другой: `<th></th>` (от *table header*).
#
# Используя эти знания, давайте создадим свою таблицу на нашей странице:

# %%
<table>
<tr>
<th>Дата</th>
<th>Имя</th>
<th>Возраст</th>
</tr>
<tr>
<td>Иванов</td>
<td>Иван</td>
<td>28</td>
</tr>
</table>

# %% [markdown]
# Можем еще добавить, например, явные границы у ячеек. Для этого вставим атрибут *border* и отрегулируем ширину.

# %%
<table border="1">
<tr>
<th>Фамилия</th>
<th>Имя</th>
<th>Возраст</th>
</tr>
<tr>
<td>Иванов</td>
<td>Иван</td>
<td>28</td>
</tr>
</table>

# %% [markdown]
# Еще добавим заголовок и на этом пока, пожалуй, закончим.

# %%
<!DOCTYPE html>
<html>
<head>
<title>Page Title</title>
</head>
<body>

<h1>Моя первая html-страница</h1>
<h2>О себе</h2>
<p>Я учусь создавать html-страницы.</p>

<table border="1">
<caption>Информация</caption>
<tr>
<th>Фамилия</th>
<th>Имя</th>
<th>Возраст</th>
</tr>
<tr>
<td>Иванов</td>
<td>Иван</td>
<td>28</td>
</tr>
</table>

</body>
</html>

# %% [markdown]
# Получившийся результат выглядит довольно-таки просто, но в то же время он помог нам осознать основные принципы построения HTML-страниц, а также сконструировать и написать одну несложную страницу своими руками. Понимая это, мы готовы переходить к непосредственному обсуждению скрейпинга и парсинга, которые и являются главным предметом нашего сегодняшнего семинара.

# %% [markdown]
# ### Web Scraping
#
# Как мы уже выяснили в предыдущем блоке, процесс веб-скрейпинга подразумевает считывание данных с некоторого веб-сайта или ресурса автоматизированным образом. Для этого процесса существует очень большое количество различных подходов, возможных сценариев действия, а также специализированных библиотек, позволяющих реализовывать все эти сценарии. Ниже мы с вами рассмотрим пример лишь одного такого алгоритма действий для осуществления веб-скрейпинга, но, разумеется, ничто вас не ограничивает от того, чтобы в будущем действовать иначе, некоторым более продвинутым образом, со своими, подобранными вами библиотеками и так далее.

# %% [markdown]
# *Один из возможных алгоритмов скрейпинга:*
#
# * указать в коде адрес интересующего сайта, откуда вы хотите скачать данные (с использованием библиотеки requests)
#
# * сохранить веб-страницу в программе (html-код вашей страницы)
#
# * выбрать данные, которые нужно собрать (с использованием библиотеки BeautifulSoup)
#
# * записать данные в csv-файл
#
# * если нужно соскрейпить несколько страниц ‒ повторить процесс для каждой из них.

# %% [markdown]
# Итак, давайте приступим к реализации этого алгоритма на практике. Нашей задачей будет являться анализ новостей с одного научно-популярного портала, выгрузка этих новостей в датафрейм pandas, а также последующее сохранение информации в csv-файл. Для начала, пожалуй, заглянем на сам [портал](https://nplus1.ru/).

# %% [markdown]
# Окей, мы посмотрели на титульную страницу портала, примерно поняли, с чем мы работаем, и можем теперь приступать непосредственно к скрейпингу.
#
# Сначала выгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам потребуется библиотека `requests`. Документация: https://requests.readthedocs.io/en/latest/
#
# Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать только при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page
# Out:
# <Response [200]>

# %% [markdown]
# Кстати, что такое Response 200, и какие еще "респонзы" бывают?

# %% [markdown]
# ### Parsing с BeautifulSoup
#
# Для продолжения работы с нашей страницей и её последующего парсинга, нам понадобится специальная библиотека: BeautifulSoup.
#
# BeautifulSoup ‒ это одна из самых распространенных python-библиотек для синтаксического разбора файлов HTML/XML. В веб-разработке слэнговым термином «суп из тегов» (tag soup) называют синтаксически или структурно некорректный HTML, написанный для веб-страницы. Именно отсюда и пошло такое необычное название для библиотеки. (Есть и другая, более весёлая гипотеза названия ‒ по [ссылке](https://aliceinwonderland.fandom.com/wiki/Turtle_Soup)).
#
# Документация BeautifulSoup: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %% [markdown]
# Итак, давайте импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы `page` код html в виде текста.
#
# Сохраним в переменную `soup` весь HTML-код страницы. HTML-код ‒ это "дерево тегов", формирующее контент и всё наполнение страницы.

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.text, 'html')

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме просмотра исходного кода (`view-source` через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>N + 1 — главное издание о науке, технике и технологиях</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=f9c00b5102d287d01698f43324336ca6" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="" property="og:type"/>
# <script type="application/ld+json">
# {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#
#   </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <section class="mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
# <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">Партнерский материал</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.3</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2024/02/22/put-cigarettes-out">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886514/conversions/30a11369c0664725d451c587debc2a3c-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886515/conversions/19431b4ea9831f8457657ebb22e4a5fc-conversion-webp.webp">
# <img alt="Туши сигарету" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886514/conversions/30a11369c0664725d451c587debc2a3c-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886515/conversions/19431b4ea9831f8457657ebb22e4a5fc-conversion-webp.webp">
# <img alt="Туши сигарету" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Туши сигарету</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Как и почему менялись привычки употребления табака
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">Подкасты</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=882">Психология</a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">Медицина</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.5</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/blog/2024/02/28/npluspodcast14">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893255/conversions/09d7b7acf7f552e030b61a40a12c1796-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893256/conversions/2ad40c9ec54c6880bf50a86808095cb5-conversion-webp.webp">
# <img alt="N + podcast: обсуждаем ПТСР с психиатром" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893255/conversions/09d7b7acf7f552e030b61a40a12c1796-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893256/conversions/2ad40c9ec54c6880bf50a86808095cb5-conversion-webp.webp">
# <img alt="N + podcast: обсуждаем ПТСР с психиатром" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">N + podcast: обсуждаем ПТСР с психиатром</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/material/2024/02/14/wild-pick-up">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886446/conversions/79d7fa7191f8139e1801afd2db09631b-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886447/conversions/d1b86fdd7caf2f74869cf59cb80e58cf-conversion-webp.webp">
# <img alt="Восемь самок" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886446/conversions/79d7fa7191f8139e1801afd2db09631b-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886447/conversions/d1b86fdd7caf2f74869cf59cb80e58cf-conversion-webp.webp">
# <img alt="Восемь самок" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Восемь самок</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Соблазните пернатых, шестиногих и чешуйчатых женщин
#                   </div>
# </div>
# </div>
# </a>
# </div>
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
# <div class="flex flex-wrap gap-2 text-tags">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">Медицина</a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">1.3</span>
# </a>
# </div>
# </div>
# <a class="" href="https://nplus1.ru/news/2024/02/29/aortic-organ">
# <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
# <div class="hidden sm:block max-height-[333px]">
# <div class="-inset-0.5 absolute group">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893429/conversions/3ad71c6ce3619ca6ab87d6fe4611678f-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893430/conversions/644eb6ca9235d7a8487541d2dc6f4144-conversion-webp.webp">
# <img alt="Аорту признали самостоятельным органом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="block sm:hidden">
# <div class="-inset-0.5 absolute max-height-[333px]">
# <picture>
# <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893429/conversions/3ad71c6ce3619ca6ab87d6fe4611678f-conversion-webp.webp">
# <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893430/conversions/644eb6ca9235d7a8487541d2dc6f4144-conversion-webp.webp">
# <img alt="Аорту признали самостоятельным органом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
# </source></source></picture>
# </div>
# </div>
# <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
# <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">Аорту признали самостоятельным органом</h3>
# <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#                     Согласно клиническому руководству EACTS/STS
#                   </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-5">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=869">
# <p class="truncate">Физика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/7">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">7.8</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/proton-strangeness">
# <div>Физики раскрыли странность протона</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
# <p class="truncate">Космонавтика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/slim-sleep-again-and-again">
# <div>Японский модуль SLIM в третий раз уснул на Луне</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=885">
# <p class="truncate">Биология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/aphantasia-am">
# <div>У людей с афантазией нашли нарушенную связь между гиппокампом и зрительной корой</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/solo-orca-vs-shark">
# <div>Косатка в одиночку убила белую акулу</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">2.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/lifestyle-factors-frh">
# <div>Нерегулярное питание и электронные сигареты поспособствовали головной боли у канадских подростков</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=889">
# <p class="truncate">Ботаника</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/mujina-no-shokudai">
# <div>Паразитирующий на грибах «барсучий подсвечник» отнесли к первому за 90 лет новому роду растений из Японии</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
# <p class="truncate">Зоология</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/ten-thousand-birds">
# <div>Орнитолог-любитель из США первым в мире увидел 10000 видов птиц</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
# <p class="truncate">Медицина</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">3.2</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/worldwide-trends-underweight-obesity">
# <div>Почти 900 миллионов человек в мире пострадало от ожирения в 2022 году</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">02.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
# <p class="truncate">Роботы и дроны</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.7</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/sanctuary-phoenix-sorting">
# <div>Человекоподобный робот Phoenix отсортировал детали с человеческой скоростью</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
# <p class="truncate">Космонавтика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/01/im-1-sleep">
# <div>Частный посадочный модуль IM-1 уснул на Луне</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
# <p class="truncate">Космонавтика</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">1.9</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/01/w-1-reentry">
# <div>Varda Space показала видео спуска в атмосфере капсулы фармацевтического спутника W-Series 1</div>
# </a>
# </div>
# </div>
# </div>
# <!-- type:default       v1-->
# <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
# <!-- type:default  [add - .flex flex-col]    v1-->
# <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
# <div class="flex flex-col">
# <!-- tags-->
# <div class="flex overflow-hidden gap-2 text-tags py-5">
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/01">
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">01.03.24</span>
# </a>
# <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=880">
# <p class="truncate">Астрономия</p>
# </a>
# <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">4.1</span>
# </a>
# </div>
# <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/01/4c-37-11">
# <div>Астрономы отыскали самую тяжелую пару сверхмассивных черных дыр</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-0 sm:mb-10">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9">
# <div class="col-span-6">
# <div class="flex flex-col gap-x-9 border-t border-gray-2 pt-5 pb-10 sm:pb-5">
# <a class="shrink-0 h-60 lg:h-72 xl:h-88 relative group" href="https://nplus1.ru/blog/2024/03/01/the-story-of-testosterone">
# <picture>
# <source media="(max-width: 768px)" srcset="https://minio.nplus1.ru/app-images/893561/conversions/65e061f9b7b6f_cover_mobile-conversion-webp.webp">
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/893560/conversions/65e061f8a2737_cover_tablet-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/893559/conversions/65e061f7a7807_cover-conversion-webp.webp">
# <img alt="«Тестостерон: гормон, который разделяет и властвует»" class="w-full h-full object-cover" loading="lazy" src="https://minio.nplus1.ru/app-images/893559/conversions/65e061f7a7807_cover-conversion-webp.webp"/>
# </source></source></source></picture>
# </a>
# <div class="flex flex-col">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags xl:pr-9">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/blog/2024/03/01">
# <span class="group-hover:text-main transition-colors duration-75">01.03.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=885">
# <span class="group-hover:text-main transition-colors duration-75">Биология</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">1.1</span>
# </a>
# </div>
# ...
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=031caa46d918adf54bd0f432e1a877eb"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# Для просмотра, честно говоря, выглядит не очень удобно. «Причешем» наш `soup` – для этого воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    N + 1 — главное издание о науке, технике и технологиях
#   </title>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
#   <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
#   <link href="/front-build/css/app.css?id=f9c00b5102d287d01698f43324336ca6" rel="stylesheet"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#f26e40" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="N + 1 - это научно-популярное издание, которое познакомит вас с природными явлениями, открытиями и технологиями, расскажет
#  просто о сложном и поможет узнать что-то новое для себя" name="description"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:title"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
#   <meta content="" property="og:type"/>
#   <script type="application/ld+json">
#    {
# 	"@context": "http://schema.org",
# 	"@type": "WebSite",
# 	"url": "https://nplus1.ru/",
# 	"name": "N + 1 — главное издание о науке, технике и технологиях",
# 	"description": "N + 1 — главное издание о науке, технике и технологиях",
# 	"image": "https://staticn1.nplus1.ru/image-new/share_snippet.png",
# 	"publisher": {
# 	"@type": "Organization",
# 		"name": "N+1",
# 		"logo": {
# 			"@type":"ImageObject",
# 			"url": "https://staticn1.nplus1.ru/image-new/logo-alt.png"
# 		},
# 		"sameAs": [
# 			"https://www.facebook.com/nplusone",
# 			"https://twitter.com/nplusodin",
# 			"https://vk.com/nplusone",
# 			"https://ok.ru/nplus1",
# 			"https://soundcloud.com/nplus_1",
# 			"https://t.me/nplusone"
# 		]
# 	},
# 	"potentialAction":{
# 		"@type":"SearchAction",
# 		"target":"https://nplus1.ru/search/{search_term_string}",
# 		"query-input":"required name=search_term_string"
# 	}
# }
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:title"/>
#   <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
#   <meta content="https://nplus1.ru/images-new/share_snippet.png" name="twitter:image"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="antialiased">
#   <!-- Top.Mail.Ru counter -->
#   <script type="text/javascript">
#    var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#   </script>
#   <noscript>
#    <div>
#     <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Top.Mail.Ru counter -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
#    <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
#     <div class="border-b border-main-gray h-full">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
#       <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
#        <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_cross_menu">
#          </use>
#         </svg>
#        </template>
#        <template v-else="">
#         <svg class="w-full h-full">
#          <use xlink:href="#n1_burger">
#          </use>
#         </svg>
#        </template>
#       </button>
#       <div>
#        <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
#       </div>
#       <a class="w-7.5 h-7.5" href="/search">
#        <svg class="w-full h-full">
#         <use xlink:href="#n1_pupa">
#         </use>
#        </svg>
#       </a>
#      </div>
#     </div>
#     <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#        <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#        <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">
#         N + offline
#        </a>
#        <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">
#         N + production
#        </a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#        <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#          О нас
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#          Сложность
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#          Рекламодателям
#         </a>
#         <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#          Авторам
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#          Игры
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#          Физика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#          Зоология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#          Астрономия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#          Генетика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#          Математика
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#          Космонавтика
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#          Археология
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#          Нейронауки
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#          На мышах
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#          Звук
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#          Красота
#         </a>
#        </div>
#        <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#          Научные закрытия
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#          ИИ спешит на помощь
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#          Когда рассеется дым
#         </a>
#         <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#          Книжная полка
#         </a>
#        </div>
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
#      <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#         О нас
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#         Сложность
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#         Рекламодателям
#        </a>
#        <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#         Авторам
#        </a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">
#         Игры
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">
#         Физика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">
#         Зоология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">
#         Астрономия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">
#         Генетика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">
#         Математика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">
#         Космонавтика
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">
#         Археология
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">
#         Нейронауки
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">
#         На мышах
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">
#         Звук
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">
#         Красота
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">
#         Научные закрытия
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">
#         ИИ спешит на помощь
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">
#         Когда рассеется дым
#        </a>
#        <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">
#         Книжная полка
#        </a>
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#        <div class="flex gap-x-5 overflow-x-auto">
#         <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">
#          N + offline
#         </a>
#         <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">
#          N + production
#         </a>
#        </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#        <ul class="flex gap-2.5">
#         <li>
#          <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tg">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_vk">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_ok">
#            </use>
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-10 h-10">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <section class="mb-10">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto mx-auto">
#      <div class="grid grid-cols-2 col-span-2 gap-0.5 n1_m_full n1_fs_main">
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=812">
#           Партнерский материал
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.3
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2024/02/22/put-cigarettes-out">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886514/conversions/30a11369c0664725d451c587debc2a3c-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886515/conversions/19431b4ea9831f8457657ebb22e4a5fc-conversion-webp.webp">
#               <img alt="Туши сигарету" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886514/conversions/30a11369c0664725d451c587debc2a3c-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886515/conversions/19431b4ea9831f8457657ebb22e4a5fc-conversion-webp.webp">
#               <img alt="Туши сигарету" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Туши сигарету
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Как и почему менялись привычки употребления табака
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=908">
#           Подкасты
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=882">
#           Психология
#          </a>
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">
#           Медицина
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.5
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/blog/2024/02/28/npluspodcast14">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893255/conversions/09d7b7acf7f552e030b61a40a12c1796-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893256/conversions/2ad40c9ec54c6880bf50a86808095cb5-conversion-webp.webp">
#               <img alt="N + podcast: обсуждаем ПТСР с психиатром" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893255/conversions/09d7b7acf7f552e030b61a40a12c1796-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893256/conversions/2ad40c9ec54c6880bf50a86808095cb5-conversion-webp.webp">
#               <img alt="N + podcast: обсуждаем ПТСР с психиатром" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            N + podcast: обсуждаем ПТСР с психиатром
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=874">
#           Зоология
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            3.1
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/material/2024/02/14/wild-pick-up">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886446/conversions/79d7fa7191f8139e1801afd2db09631b-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886447/conversions/d1b86fdd7caf2f74869cf59cb80e58cf-conversion-webp.webp">
#               <img alt="Восемь самок" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/886446/conversions/79d7fa7191f8139e1801afd2db09631b-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/886447/conversions/d1b86fdd7caf2f74869cf59cb80e58cf-conversion-webp.webp">
#               <img alt="Восемь самок" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Восемь самок
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Соблазните пернатых, шестиногих и чешуйчатых женщин
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#        <div class="absolute z-10 top-5 inset-x-4 md:inset-x-5">
#         <div class="flex flex-wrap gap-2 text-tags">
#          <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center text-white text-xs sm:text-sm hover:text-main" href="https://nplus1.ru/search?tags=873">
#           Медицина
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full text-white hover:text-main" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 overflow-hidden text-ellipsis whitespace-nowrap">
#            1.3
#           </span>
#          </a>
#         </div>
#        </div>
#        <a class="" href="https://nplus1.ru/news/2024/02/29/aortic-organ">
#         <div class="relative order-1 sm:order-1 overflow-hidden h-full sm:h-48 md:h-60 lg:h-72 xl:h-88">
#          <div class="hidden sm:block max-height-[333px]">
#           <div class="-inset-0.5 absolute group">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893429/conversions/3ad71c6ce3619ca6ab87d6fe4611678f-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893430/conversions/644eb6ca9235d7a8487541d2dc6f4144-conversion-webp.webp">
#               <img alt="Аорту признали самостоятельным органом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="block sm:hidden">
#           <div class="-inset-0.5 absolute max-height-[333px]">
#            <picture>
#             <source media="(min-width: 640px)" srcset="https://minio.nplus1.ru/app-images/893429/conversions/3ad71c6ce3619ca6ab87d6fe4611678f-conversion-webp.webp">
#              <source media="(max-width: 639px)" srcset="https://minio.nplus1.ru/app-images/893430/conversions/644eb6ca9235d7a8487541d2dc6f4144-conversion-webp.webp">
#               <img alt="Аорту признали самостоятельным органом" class="w-full h-full object-cover brightness-75" loading="lazy" src="https://staticn1.nplus1.ru/image-new/blank.jpeg"/>
#              </source>
#             </source>
#            </picture>
#           </div>
#          </div>
#          <div class="absolute bottom-5 inset-x-4 md:inset-x-5">
#           <h3 class="text-white text-14 md:text-22 xl:text-32 mb-1">
#            Аорту признали самостоятельным органом
#           </h3>
#           <div class="text-white max-h-[90px] overflow-hidden sm:max-h-full text-14 md:text-22 xl:text-34 font-serif font-light font-spectral">
#            Согласно клиническому руководству EACTS/STS
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#    </section>
#    <section class="mb-0 sm:mb-5">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 md:gap-x-9 relative">
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=869">
#           <p class="truncate">
#            Физика
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/7">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            7.8
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/proton-strangeness">
#          <div>
#           Физики раскрыли странность протона
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=871">
#           <p class="truncate">
#            Космонавтика
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/slim-sleep-again-and-again">
#          <div>
#           Японский модуль SLIM в третий раз уснул на Луне
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=885">
#           <p class="truncate">
#            Биология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.2
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/aphantasia-am">
#          <div>
#           У людей с афантазией нашли нарушенную связь между гиппокампом и зрительной корой
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#           <p class="truncate">
#            Зоология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.9
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/solo-orca-vs-shark">
#          <div>
#           Косатка в одиночку убила белую акулу
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            2.2
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/lifestyle-factors-frh">
#          <div>
#           Нерегулярное питание и электронные сигареты поспособствовали головной боли у канадских подростков
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=889">
#           <p class="truncate">
#            Ботаника
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.1
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/mujina-no-shokudai">
#          <div>
#           Паразитирующий на грибах «барсучий подсвечник» отнесли к первому за 90 лет новому роду растений из Японии
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=874">
#           <p class="truncate">
#            Зоология
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.7
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/ten-thousand-birds">
#          <div>
#           Орнитолог-любитель из США первым в мире увидел 10000 видов птиц
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=873">
#           <p class="truncate">
#            Медицина
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/3">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            3.2
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/worldwide-trends-underweight-obesity">
#          <div>
#           Почти 900 миллионов человек в мире пострадало от ожирения в 2022 году
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
#         <div class="flex overflow-hidden gap-2 text-tags py-5">
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/news/2024/03/02">
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            02.03.24
#           </span>
#          </a>
#          <a class="inline-block relative pl-2 flex inline-flex items-center before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 transition-colors duration-75 hover:text-main trunc" href="https://nplus1.ru/search?tags=883">
#           <p class="truncate">
#            Роботы и дроны
#           </p>
#          </a>
#          <a class="group inline-block relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center max-w-full" href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 stroke-current">
#            <use xlink:href="#n1_star">
#            </use>
#           </svg>
#           <span class="transition-colors duration-75 group-hover:text-main overflow-hidden text-ellipsis whitespace-nowrap">
#            1.7
#           </span>
#          </a>
#         </div>
#         <a class="n1_climb_4 transition-colors duration-75 hover:text-main inline-block mb-10 sm:mb-5 font-spectral leading-24" href="https://nplus1.ru/news/2024/03/02/sanctuary-phoenix-sorting">
#          <div>
#           Человекоподобный робот Phoenix отсортировал детали с человеческой скоростью
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- type:default       v1-->
#      <div class="col-span-6 sm:col-span-6 lg:col-span-4 xl:col-span-3">
#       <!-- type:default  [add - .flex flex-col]    v1-->
#       <div class="flex flex-col border-t border-gray-2 text-20 pb-10 sm:pb-5">
#        <div class="flex flex-col">
#         <!-- tags-->
# ...
#           </svg>
#          </a>
#         </li>
#         <li class="w-12">
#          <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#           <svg class="w-12 h-12">
#            <use xlink:href="#n1_tw">
#            </use>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M11 5V17">
#    </path>
#    <path d="M6.75781 6.75781L15.2431 15.2431">
#    </path>
#    <path d="M17 11L5 11">
#    </path>
#    <path d="M15.2422 6.75781L6.75691 15.2431">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle cx="25" cy="25" r="24.5">
#    </circle>
#    <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z">
#    </path>
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#   </svg>
#   <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625">
#     </animate>
#    </path>
#   </svg>
#   <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
#    <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9">
#    </path>
#    <path d="M13 1L1 13" stroke="#F9F9F9">
#    </path>
#   </svg>
#   <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#    <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor">
#    </path>
#   </svg>
#   <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
#    <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd">
#    </path>
#    <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z">
#    </path>
#   </svg>
#   <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5">
#    </rect>
#    <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <mask id="path-1-inside-1_2694_77554">
#     <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd">
#     </path>
#    </mask>
#    <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd">
#    </path>
#    <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#    <circle class="stroke-current" cx="25" cy="25" r="24.5">
#    </circle>
#    <path class="stroke-current" d="M18 35V15L36 25L18 35Z">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
#    <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd">
#    </path>
#   </svg>
#   <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <line stroke="#32363A" x2="30" y1="6.5" y2="6.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="23.5" y2="23.5">
#    </line>
#    <line stroke="#32363A" x2="30" y1="15" y2="15">
#    </line>
#   </svg>
#   <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#    <path d="M4 4L26 26" stroke="#32363A">
#    </path>
#    <path d="M26 4L4 26" stroke="#32363A">
#    </path>
#   </svg>
#   <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
#    <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z">
#    </path>
#   </svg>
#   <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#    <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round">
#    </path>
#   </svg>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script src="/front-build/js/app.js?id=031caa46d918adf54bd0f432e1a877eb">
#   </script>
#   <!-- Yandex.Metrika counter 2-->
#   <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
#     <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
#   </script>
#   <script>
#    window.yaContextCb = window.yaContextCb || []
#   </script>
#   <script async="" src="https://yandex.ru/ads/system/context.js">
#   </script>
#   <script>
#    if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# В такой выдаче ориентироваться чуть-чуть удобнее (но при желании, то же самое можно увидеть в браузере, на большом экране).

# %% [markdown]
# Итак, что же нам делать дальше? Как на основе этого сырого html-кода получить доступ к новостям на портале?
#
# Для того чтобы это сделать, давайте с главной страницы сайта соберем все ссылки, из которых потом выделим ссылки на страницы с новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`.
#
# Помочь нам в поиске ссылок может функция **`soup.find('a')`**, которая найдет первый в дереве тег `<a>`.
#
# Если нам нужно найти не только первый элемент, а все элементы по определенному признаку, следует использовать функцию **`soup.find_all('a')`**

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /search
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=772
# https://nplus1.ru/search?tags=778
# https://nplus1.ru/search?tags=917
# https://nplus1.ru/search?tags=918
# https://nplus1.ru/search?tags=824
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# https://nplus1.ru/search?tags=946
# https://nplus1.ru/search?tags=869
# https://nplus1.ru/search?tags=874
# https://nplus1.ru/search?tags=880
# https://nplus1.ru/search?tags=768
# https://nplus1.ru/search?tags=890
# https://nplus1.ru/search?tags=871
# https://nplus1.ru/search?tags=876
# https://nplus1.ru/search?tags=775
# https://nplus1.ru/search?tags=767
# https://nplus1.ru/search?tags=771
# https://nplus1.ru/search?tags=772
# https://nplus1.ru/search?tags=778
# https://nplus1.ru/search?tags=917
# https://nplus1.ru/search?tags=918
# https://nplus1.ru/search?tags=824
# https://offline.nplus1.ru/
# https://nplus.pro/
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin
# https://nplus1.ru/search?tags=812
# /material/difficulty/3
# https://nplus1.ru/material/2024/02/22/put-cigarettes-out
# https://nplus1.ru/search?tags=908
# https://nplus1.ru/search?tags=882
# https://nplus1.ru/search?tags=873
# /material/difficulty/3
# https://nplus1.ru/blog/2024/02/28/npluspodcast14
# https://nplus1.ru/search?tags=874
# /material/difficulty/3
# https://nplus1.ru/material/2024/02/14/wild-pick-up
# https://nplus1.ru/search?tags=873
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/aortic-organ
# /news/2024/03/02
# https://nplus1.ru/search?tags=869
# /material/difficulty/7
# https://nplus1.ru/news/2024/03/02/proton-strangeness
# /news/2024/03/02
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/02/slim-sleep-again-and-again
# /news/2024/03/02
# https://nplus1.ru/search?tags=885
# /material/difficulty/3
# https://nplus1.ru/news/2024/03/02/aphantasia-am
# /news/2024/03/02
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/02/solo-orca-vs-shark
# /news/2024/03/02
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/02/lifestyle-factors-frh
# /news/2024/03/02
# https://nplus1.ru/search?tags=889
# /material/difficulty/3
# https://nplus1.ru/news/2024/03/02/mujina-no-shokudai
# /news/2024/03/02
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/02/ten-thousand-birds
# /news/2024/03/02
# https://nplus1.ru/search?tags=873
# /material/difficulty/3
# https://nplus1.ru/news/2024/03/02/worldwide-trends-underweight-obesity
# /news/2024/03/02
# https://nplus1.ru/search?tags=883
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/02/sanctuary-phoenix-sorting
# /news/2024/03/01
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/01/im-1-sleep
# /news/2024/03/01
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/01/w-1-reentry
# /news/2024/03/01
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/03/01/4c-37-11
# https://nplus1.ru/blog/2024/03/01/the-story-of-testosterone
# /blog/2024/03/01
# https://nplus1.ru/search?tags=885
# /material/difficulty/1
# https://nplus1.ru/blog/2024/03/01/the-story-of-testosterone
# https://nplus1.ru/blog/2024/02/28/the-merchants-of-siberia
# /blog/2024/02/28
# https://nplus1.ru/search?tags=817
# /material/difficulty/1
# https://nplus1.ru/blog/2024/02/28/the-merchants-of-siberia
# /news/2024/03/01
# https://nplus1.ru/search?tags=871
# /material/difficulty/3
# https://nplus1.ru/news/2024/03/01/im-1-ilo
# /news/2024/03/01
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/posttraumatic-epilepsy-dementia
# https://nplus1.ru/material/2024/02/05/russian-op-future
# /material/2024/02/05
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2024/02/05/russian-op-future
# https://nplus1.ru/material/2024/01/22/risk-modification
# https://nplus1.ru/search?tags=812
# /material/difficulty/2
# https://nplus1.ru/material/2024/01/22/risk-modification
# /blog/2024/02/26
# https://nplus1.ru/search?tags=877
# /material/difficulty/1
# /author/ast
# https://nplus1.ru/blog/2024/02/26/accidental-gods
# /news/2024/03/01
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/problem-solving-bird
# /news/2024/03/01
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/01/suboptimal-asthma-care-ghg
# /news/2024/03/01
# https://nplus1.ru/search?tags=817
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/man-eating-wolves
# https://nplus1.ru/material/2024/01/06/metamorphoses
# /material/2024/01/06
# https://nplus1.ru/search?tags=874
# /material/difficulty/4
# https://nplus1.ru/material/2024/01/06/metamorphoses
# /news/2024/03/01
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/brokeback-whale
# /news/2024/03/01
# https://nplus1.ru/search?tags=872
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/predators-in-changing-climate
# https://nplus1.ru/material/2024/01/05/abies
# /material/2024/01/05
# https://nplus1.ru/search?tags=889
# /material/difficulty/2
# https://nplus1.ru/material/2024/01/05/abies
# https://nplus1.ru/material/2024/01/04/new-year-blues
# https://nplus1.ru/search?tags=882
# /material/difficulty/4
# https://nplus1.ru/material/2024/01/04/new-year-blues
# /blog/2024/02/22
# https://nplus1.ru/search?tags=817
# /material/difficulty/1
# /author/nlo
# https://nplus1.ru/blog/2024/02/22/maiden-with-a-banner
# /news/2024/03/01
# https://nplus1.ru/search?tags=876
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/trawniki-from-treblinka
# /news/2024/03/01
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/03/01/simple-vs-radical-hysterectomy
# /news/2024/03/01
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/03/01/dimorphos-shape
# https://nplus1.ru/material/2024/01/02/wild-home-alone
# /material/2024/01/02
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/material/2024/01/02/wild-home-alone
# /news/2024/03/01
# https://nplus1.ru/search?tags=873
# /material/difficulty/1
# https://nplus1.ru/news/2024/03/01/dont-pack-to-go
# /news/2024/02/29
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/02/29/hl-taurus
# https://nplus1.ru/material/2024/01/01/citrus-evolution
# /material/2024/01/01
# https://nplus1.ru/search?tags=889
# /material/difficulty/4
# https://nplus1.ru/material/2024/01/01/citrus-evolution
# https://nplus1.ru/material/2023/12/30/new-year-socks
# https://nplus1.ru/search?tags=881
# /material/difficulty/4
# https://nplus1.ru/material/2023/12/30/new-year-socks
# /blog/2024/02/19
# https://nplus1.ru/search?tags=885
# /material/difficulty/1
# /author/ast
# https://nplus1.ru/blog/2024/02/19/the-romance-of-reality
# /news/2024/02/29
# https://nplus1.ru/search?tags=892
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/sykorsky-hex-vtol
# /news/2024/02/29
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/mars-drone-debris
# /news/2024/02/29
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/29/polytrauma-bear-attacking
# https://nplus1.ru/material/2023/12/28/series-therapy
# /material/2023/12/28
# https://nplus1.ru/search?tags=812
# /material/difficulty/3
# https://nplus1.ru/material/2023/12/28/series-therapy
# /news/2024/02/29
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/02/29/jwst-reionization
# /news/2024/02/29
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/mercury-in-tuna
# https://nplus1.ru/material/2023/12/28/mind-crib
# /material/2023/12/28
# https://nplus1.ru/search?tags=885
# /material/difficulty/5
# https://nplus1.ru/material/2023/12/28/mind-crib
# https://nplus1.ru/material/2023/12/27/new-years-commotion
# https://nplus1.ru/search?tags=812
# /material/difficulty/5
# https://nplus1.ru/material/2023/12/27/new-years-commotion
# /blog/2024/02/15
# https://nplus1.ru/search?tags=817
# /material/difficulty/1
# /author/nlo
# https://nplus1.ru/blog/2024/02/15/an-academy-at-the-court-of-the-tsars
# /news/2024/02/29
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/im-1-new-photos
# /news/2024/02/29
# https://nplus1.ru/search?tags=885
# /material/difficulty/4
# https://nplus1.ru/news/2024/02/29/tail-loss-genes
# /news/2024/02/29
# https://nplus1.ru/search?tags=873
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/cannabis-and-heart
# https://nplus1.ru/material/2023/12/26/yandex-delivery-robot
# /material/2023/12/26
# https://nplus1.ru/search?tags=812
# /material/difficulty/2
# https://nplus1.ru/material/2023/12/26/yandex-delivery-robot
# /news/2024/02/29
# https://nplus1.ru/search?tags=872
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/food-biodiversity
# /news/2024/02/29
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/02/29/earth-as-exoplanet
# https://nplus1.ru/material/2023/12/25/decade-of-science
# /material/2023/12/25
# https://nplus1.ru/search?tags=812
# /material/difficulty/2
# https://nplus1.ru/material/2023/12/25/decade-of-science
# https://nplus1.ru/material/2023/12/22/airi-neurips
# https://nplus1.ru/search?tags=812
# /material/difficulty/5
# https://nplus1.ru/material/2023/12/22/airi-neurips
# /blog/2024/02/15
# https://nplus1.ru/search?tags=817
# /material/difficulty/2
# /author/yulli-uletova
# https://nplus1.ru/blog/2024/02/15/home-made-promotion
# /news/2024/02/29
# https://nplus1.ru/search?tags=873
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/29/acupuncture-ptsd
# /news/2024/02/29
# https://nplus1.ru/search?tags=870
# /material/difficulty/6
# https://nplus1.ru/news/2024/02/29/chiral-nanographene-synthesis
# /news/2024/02/29
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/29/heloderma-suspectum
# https://nplus1.ru/material/2023/12/20/cool-down-volgograd
# /material/2023/12/20
# https://nplus-1.ru/search?tags=872
# /material/difficulty/3
# https://nplus1.ru/material/2023/12/20/cool-down-volgograd
# /news/2024/02/29
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/02/29/earth-as-exoplanet
# /news/2024/02/24
# https://nplus1.ru/search?tags=871
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/24/im-1-photos
# /news/2024/02/16
# https://nplus1.ru/search?tags=877
# /material/difficulty/3
# https://nplus1.ru/news/2024/02/16/pull-the-plug
# /news/2024/02/28
# https://nplus1.ru/search?tags=872
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/28/vi_vse_eshe_kipyatite
# /news/2024/02/17
# https://nplus1.ru/search?tags=876
# /material/difficulty/3
# https://nplus1.ru/news/2024/02/17/vindija-cave
# /news/2024/02/21
# https://nplus1.ru/search?tags=874
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/21/prionops-alberti
# /news/2024/02/26
# https://nplus1.ru/search?tags=874
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/26/black-bullfinch
# /news/2022/01/25
# https://nplus1.ru/search?tags=873
# https://nplus1.ru/search?tags=766
# /material/difficulty/3
# https://nplus1.ru/news/2022/01/25/coronavirus-survivial
# /blog/2023/03/31
# https://nplus1.ru/search?tags=817
# /material/difficulty/1
# https://nplus1.ru/blog/2023/03/31/das-neue-unbehagen
# /news/2024/02/17
# https://nplus1.ru/search?tags=876
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/17/ochre-from-australia
# /news/2022/08/26
# https://nplus1.ru/search?tags=874
# /material/difficulty/5
# https://nplus1.ru/news/2022/08/26/rabbits
# /news/2024/02/08
# https://nplus1.ru/search?tags=880
# /material/difficulty/4
# https://nplus1.ru/news/2024/02/08/mimas-ocean-yes
# /news/2024/03/02
# https://nplus1.ru/search?tags=869
# /material/difficulty/7
# https://nplus1.ru/news/2024/03/02/proton-strangeness
# /blog/2024/02/19
# https://nplus1.ru/search?tags=885
# /material/difficulty/1
# https://nplus1.ru/blog/2024/02/19/the-romance-of-reality
# /news/2024/02/08
# https://nplus1.ru/search?tags=876
# /material/difficulty/2
# https://nplus1.ru/news/2024/02/08/black-henbane
# /news/2024/02/19
# https://nplus1.ru/search?tags=869
# /material/difficulty/8
# https://nplus1.ru/news/2024/02/19/schroedinger-cats
# /news/2024/02/29
# https://nplus1.ru/search?tags=871
# /material/difficulty/1
# https://nplus1.ru/news/2024/02/29/mars-drone-debris
# /news/2024/02/10
# https://nplus1.ru/search?tags=880
# /material/difficulty/5
# https://nplus1.ru/news/2024/02/10/3c-84-eht
# /news/2024/02/24
# https://nplus1.ru/search?tags=874
# /material/difficulty/3
# https://nplus1.ru/news/2024/02/24/gaikotsu-panda-hoya
# /news/2024/03/02
# https://nplus1.ru/search?tags=889
# /material/difficulty/3
# https://nplus1.ru/news/2024/03/02/mujina-no-shokudai
# https://nplus1.ru/material/2024/02/07/izucat-izobretat-i-otkryvat
# /material/2024/02/07
# https://nplus1.ru/search?tags=812
# /material/difficulty/1
# https://nplus1.ru/material/2024/02/07/izucat-izobretat-i-otkryvat
# https://nplus1.ru/material/2024/01/30/outstanding-op-software
# /material/2024/01/30
# https://nplus1.ru/search?tags=812
# https://nplus1.ru/search?tags=886
# /material/difficulty/1
# https://nplus1.ru/material/2024/01/30/outstanding-op-software
# https://nplus1.ru/news/2024/02/12/chiral-currents
# https://nplus1.ru/news/2024/02/12/fight-cancer-with-cancer
# https://nplus1.ru/news/2024/02/13/ms-enantiomers-separation
# https://nplus1.ru/news/2024/02/14/mars-volcanoes-evolution
# https://nplus1.ru/news/2024/02/15/magnetars-and-frbs
# https://nplus1.ru/news/2024/02/16/titan-ocean-habitability
# https://nplus1.ru/news/2024/02/19/five-new-isotopes
# https://nplus1.ru/news/2024/02/19/intestinal-rotation-redox-imbalance
# https://nplus1.ru/news/2024/02/19/schroedinger-cats
# https://nplus1.ru/news/2024/02/20/nickel-phosphine-oa
# https://nplus1.ru/news/2024/02/22/vitamin-and-death
# https://nplus1.ru/news/2024/02/23/water-enhancing-photochemistry
# https://nplus1.ru/news/2024/02/23/hydroactivity-tno
# https://nplus1.ru/news/2024/02/29/chiral-nanographene-synthesis
# https://nplus1.ru/news/2024/03/02/proton-strangeness
# https://nplus1.ru/about
# https://nplus1.ru/difficult
# https://nplus1.ru/adv
# https://nplus1.ru/blog/2022/04/01/samotek
# /cdn-cgi/l/email-protection#7d13113d130d11080e4c530f08
# /cdn-cgi/l/email-protection#543d3a323b143a24382127657a2621
# /personal-data-policy
# https://t.me/nplusone
# https://vk.com/nplusone
# https://ok.ru/nplus1
# https://twitter.com/nplusodin

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
#     print(link)
    if '/news' in link.get('href'):
        if 'https://' in link.get('href'):
            urls.append(link.get('href'))
urls
# Out:
# ['https://nplus1.ru/news/2024/02/29/aortic-organ',
#  'https://nplus1.ru/news/2024/03/02/proton-strangeness',
#  'https://nplus1.ru/news/2024/03/02/slim-sleep-again-and-again',
#  'https://nplus1.ru/news/2024/03/02/aphantasia-am',
#  'https://nplus1.ru/news/2024/03/02/solo-orca-vs-shark',
#  'https://nplus1.ru/news/2024/03/02/lifestyle-factors-frh',
#  'https://nplus1.ru/news/2024/03/02/mujina-no-shokudai',
#  'https://nplus1.ru/news/2024/03/02/ten-thousand-birds',
#  'https://nplus1.ru/news/2024/03/02/worldwide-trends-underweight-obesity',
#  'https://nplus1.ru/news/2024/03/02/sanctuary-phoenix-sorting',
#  'https://nplus1.ru/news/2024/03/01/im-1-sleep',
#  'https://nplus1.ru/news/2024/03/01/w-1-reentry',
#  'https://nplus1.ru/news/2024/03/01/4c-37-11',
#  'https://nplus1.ru/news/2024/03/01/im-1-ilo',
#  'https://nplus1.ru/news/2024/03/01/posttraumatic-epilepsy-dementia',
#  'https://nplus1.ru/news/2024/03/01/problem-solving-bird',
#  'https://nplus1.ru/news/2024/03/01/suboptimal-asthma-care-ghg',
#  'https://nplus1.ru/news/2024/03/01/man-eating-wolves',
#  'https://nplus1.ru/news/2024/03/01/brokeback-whale',
#  'https://nplus1.ru/news/2024/03/01/predators-in-changing-climate',
#  'https://nplus1.ru/news/2024/03/01/trawniki-from-treblinka',
#  'https://nplus1.ru/news/2024/03/01/simple-vs-radical-hysterectomy',
#  'https://nplus1.ru/news/2024/03/01/dimorphos-shape',
#  'https://nplus1.ru/news/2024/03/01/dont-pack-to-go',
#  'https://nplus1.ru/news/2024/02/29/hl-taurus',
#  'https://nplus1.ru/news/2024/02/29/sykorsky-hex-vtol',
#  'https://nplus1.ru/news/2024/02/29/mars-drone-debris',
#  'https://nplus1.ru/news/2024/02/29/polytrauma-bear-attacking',
#  'https://nplus1.ru/news/2024/02/29/jwst-reionization',
#  'https://nplus1.ru/news/2024/02/29/mercury-in-tuna',
#  'https://nplus1.ru/news/2024/02/29/im-1-new-photos',
#  'https://nplus1.ru/news/2024/02/29/tail-loss-genes',
#  'https://nplus1.ru/news/2024/02/29/cannabis-and-heart',
#  'https://nplus1.ru/news/2024/02/29/food-biodiversity',
#  'https://nplus1.ru/news/2024/02/29/earth-as-exoplanet',
#  'https://nplus1.ru/news/2024/02/29/acupuncture-ptsd',
#  'https://nplus1.ru/news/2024/02/29/chiral-nanographene-synthesis',
#  'https://nplus1.ru/news/2024/02/29/heloderma-suspectum',
#  'https://nplus1.ru/news/2024/02/29/earth-as-exoplanet',
#  'https://nplus1.ru/news/2024/02/24/im-1-photos',
#  'https://nplus1.ru/news/2024/02/16/pull-the-plug',
#  'https://nplus1.ru/news/2024/02/28/vi_vse_eshe_kipyatite',
#  'https://nplus1.ru/news/2024/02/17/vindija-cave',
#  'https://nplus1.ru/news/2024/02/21/prionops-alberti',
#  'https://nplus1.ru/news/2024/02/26/black-bullfinch',
#  'https://nplus1.ru/news/2022/01/25/coronavirus-survivial',
#  'https://nplus1.ru/news/2024/02/17/ochre-from-australia',
#  'https://nplus1.ru/news/2022/08/26/rabbits',
#  'https://nplus1.ru/news/2024/02/08/mimas-ocean-yes',
#  'https://nplus1.ru/news/2024/03/02/proton-strangeness',
#  'https://nplus1.ru/news/2024/02/08/black-henbane',
#  'https://nplus1.ru/news/2024/02/19/schroedinger-cats',
#  'https://nplus1.ru/news/2024/02/29/mars-drone-debris',
#  'https://nplus1.ru/news/2024/02/10/3c-84-eht',
#  'https://nplus1.ru/news/2024/02/24/gaikotsu-panda-hoya',
#  'https://nplus1.ru/news/2024/03/02/mujina-no-shokudai',
#  'https://nplus1.ru/news/2024/02/12/chiral-currents',
#  'https://nplus1.ru/news/2024/02/12/fight-cancer-with-cancer',
#  'https://nplus1.ru/news/2024/02/13/ms-enantiomers-separation',
#  'https://nplus1.ru/news/2024/02/14/mars-volcanoes-evolution',
#  'https://nplus1.ru/news/2024/02/15/magnetars-and-frbs',
#  'https://nplus1.ru/news/2024/02/16/titan-ocean-habitability',
#  'https://nplus1.ru/news/2024/02/19/five-new-isotopes',
#  'https://nplus1.ru/news/2024/02/19/intestinal-rotation-redox-imbalance',
#  'https://nplus1.ru/news/2024/02/19/schroedinger-cats',
#  'https://nplus1.ru/news/2024/02/20/nickel-phosphine-oa',
#  'https://nplus1.ru/news/2024/02/22/vitamin-and-death',
#  'https://nplus1.ru/news/2024/02/23/water-enhancing-photochemistry',
#  'https://nplus1.ru/news/2024/02/23/hydroactivity-tno',
#  'https://nplus1.ru/news/2024/02/29/chiral-nanographene-synthesis',
#  'https://nplus1.ru/news/2024/03/02/proton-strangeness']

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `urls` в цикле. Посмотрим на новость с индексом 1 (у вас, конечно, может быть другая, новости обновляются).

# %%
url0 = urls[1]

page0 = requests.get(url0)
soup0 = BeautifulSoup(page0.text, 'html')
soup0
# Out:
# <!DOCTYPE html>
# <html lang="ru" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Физики раскрыли странность протона. Странный кварк вносит вклад в массу протона со значимостью более трех стандартных отклонений</title>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" rel="preload" type="font/woff2"/>
# <link href="/front-build/css/main.css?id=9b496fbb252428c03791da99722528ab" rel="stylesheet"/>
# <link href="/front-build/css/app.css?id=f9c00b5102d287d01698f43324336ca6" rel="stylesheet"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#f26e40" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#f26e40" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://nplus1.ru/news/2024/03/02/proton-strangeness" rel="canonical"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
# <!-- End Google Tag Manager -->
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>
# <meta content="Физики раскрыли странность протона" property="og:title"/>
# <meta content="https://minio.nplus1.ru/app-images/894593/65e3641179ef8_cover_share.jpg" property="og:image"/>
# <meta content="https://nplus1.ru/news/2024/03/02/proton-strangeness" property="og:url"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="2024-03-02" itemprop="datePublished"/>
# <!-- amp page -->
# <link href="https://nplus1.ru/news/2024/03/02/proton-strangeness/amp" rel="amphtml"/>
# <meta content="2024-03-02" itemprop="datePublished"/>
# <meta content="Дмитрий Рудик" name="mediator_author"/>
# <meta content="Дмитрий Рудик" name="author"/>
# <meta content="" name="copyright"/>
# <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2024/03/02/proton-strangeness"
#       },
#       "headline": "Физики раскрыли странность протона",
#       "description": "Странный кварк вносит вклад в массу протона со значимостью более трех стандартных отклонений",
#             "image": "https://minio.nplus1.ru/app-images/894593/65e3641179ef8_cover_share.jpg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Дмитрий Рудик",
#                 "image": "https://staticn1.nplus1.ru/image-new/logo-alt.png",
#               "url": "https://nplus1.ru/author/dmitriirudik"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/894593/65e3641179ef8_cover_share.jpg"
#       }
#     },
#     "datePublished": "2024-03-02",
#       "dateModified": "2024-03-02"
#     }
#
#
#
#     </script>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="Физики раскрыли странность протона" name="twitter:title"/>
# <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>
# <meta content="https://minio.nplus1.ru/app-images/894593/65e3641179ef8_cover_share.jpg" name="twitter:image"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# </head>
# <body class="antialiased">
# <!-- Top.Mail.Ru counter -->
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
# <noscript><div><img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;"/></div></noscript>
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray" id="appfront">
# <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50" data-ref-header="" ref="headerRef">
# <div class="absolute bg-main-gray/5 bottom-0 left-0 top-0" id="progressBar" style="z-index: -1"></div>
# <div class="border-b border-main-gray h-full">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full" data-ref-header-container="" ref="headerContainerRef">
# <button aria-label="Go" class="w-7.5 h-7.5" data-ref-header-menu-btn="" id="topMenuBtn" ref="headerMenuBtnRef">
# <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
# <svg class="w-full h-full">
# <use xlink:href="#n1_cross_menu"></use>
# </svg>
# </template>
# <template v-else="">
# <svg class="w-full h-full">
# <use xlink:href="#n1_burger"></use>
# </svg>
# </template>
# </button>
# <div>
# <a href="/">
# <img alt="as" height="23" loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" width="57"/>
# </a>
# </div>
# <a class="w-7.5 h-7.5" href="/search">
# <svg class="w-full h-full">
# <use xlink:href="#n1_pupa"></use>
# </svg>
# </a>
# </div>
# </div>
# <nav :style="stylesNavDesktop" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden" id="navMenu" v-if="isOpenDesktopMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
# <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75" href="https://nplus.pro/">N + production</a>
# </div>
# <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
# <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота</a>
# </div>
# <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка</a>
# </div>
# </div>
# <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav :style="stylesNavMobile" class="relative bg-white max-h-0 n1_top_nav overflow-hidden" id="mobNavMenu" v-if="isOpenMobileMenu">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
# <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/about">
#                 О нас
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/difficult" target="_blank">
#                 Сложность
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/adv" target="_blank">
#                 Рекламодателям
#               </a>
# <a class="hover:text-main transition-colors duration-75" href="https://nplus1.ru/blog/2022/04/01/samotek" target="_blank">
#                 Авторам
#               </a>
# </div>
# <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=946">Игры
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=869">Физика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=890">Математика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=876">Археология
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=771">Звук
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=772">Красота
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
# <a class="hover:underline transition-colors duration-75" href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
# </div>
# <div class="max-w-full flex py-5 border-t border-gray-2">
# <div class="flex gap-x-5 overflow-x-auto">
# <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
# <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
# </div>
# </div>
# <div class="pt-5 pb-10 border-t border-gray-2 text-18">
# <ul class="flex gap-2.5">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-10 h-10">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <app-heading-nav></app-heading-nav>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-7.5 relative overflow-hidden" data-heading-wrap="">
# <!--tags-->
# <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
# <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
# <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
# <span class="group-hover:text-main transition-colors duration-75">21:54</span>
# </span>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/news/2024/03/02">
# <span class="group-hover:text-main transition-colors duration-75">02.03.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="/material/difficulty/7">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">7.8</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center" href="https://nplus1.ru/search?tags=869">
# <span class="group-hover:text-main transition-colors duration-75">Физика</span>
# </a>
# </div>
# <div class="hidden lg:flex items-center gap-x-2">
# <a class="group" href="https://nplus1.ru/material-print/67731" target="_blank">
# <svg class="group-hover:text-main transition-colors duration-75 stroke-current" fill="none" height="30" viewbox="0 0 22 30" width="22" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" width="21" x="0.5" y="0.5"></rect>
# <line x1="4" x2="18" y1="7.5" y2="7.5"></line>
# <line x1="4" x2="18" y1="21.5" y2="21.5"></line>
# <line x1="4" x2="18" y1="14.5" y2="14.5"></line>
# </svg>
# </a>
# <app-copy-material link="https://nplus1.ru/news/2024/03/02/proton-strangeness" type="full-2"></app-copy-material>
# </div>
# <div class="w-full flex flex-col mt-5">
# </div>
# </div>
# <!--dotes menu mobile-->
# <template v-if="isMobile">
# <button class="absolute flex right-5 top-5 z-30 text-main-black">
# <svg class="fill-current" fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }" ref="mobileDotsMenuRef">
# <app-copy-material link="https://nplus1.ru/news/2024/03/02/proton-strangeness" type="mobile"></app-copy-material>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"></path>
# </svg>
# </button>
# <button aria-label="Go" class="group">
# <svg class="group-focus:text-main transition-colors duration-75 stroke-current" fill="none" height="40" viewbox="0 0 30 40" width="30" xmlns="http://www.w3.org/2000/svg">
# <rect height="39" width="28.3333" x="0.833984" y="0.5"></rect>
# <line x1="5.66732" x2="24.334" y1="10.1665" y2="10.1665"></line>
# <line x1="5.66732" x2="24.334" y1="28.8335" y2="28.8335"></line>
# <line x1="5.66732" x2="24.334" y1="19.5" y2="19.5"></line>
# </svg>
# </button>
# </div>
# </template>
# <!-- main image -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
# <div class="flex flex-col">
# <h1 class="text-34 md:text-42 xl:text-52 break-words">
#             Физики раскрыли странность протона
#           </h1>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Странный кварк вносит вклад в массу протона со значимостью более трех стандартных отклонений</p>
# <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
# <span class="whitespace-nowrap">
# <a class="underline" href="/author/dmitriirudik">Дмитрий Рудик</a>
# </span>
# </div>
# <div class="mb-14" data-lmb-0="">
# <basegallerymain :gid="69813"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">Китайским физикам удалось выделить вклад странного кварка в массу протона. Он оказался равен 338 или 456 мегаэлектровольта в зависимости от выбранной модели со статистической значимостью 3,2 или 7,1 стандартных отклонений соответственно. Исследование <a href="https://journals.aps.org/prd/abstract/10.1103/PhysRevD.109.036034" rel="noreferrer noopener" target="_blank">опубликовано</a> в журнале Physical Review D.</p></div>
# <div class="n1_material text-18"><p class="mb-6">Большая часть видимой материи во Вселенной состоит из протонов и нейтронов. Сами же протоны и нейтроны, согласно партонной модели, состоят из кварков и глюонов, а также из кваркового моря — постоянно рождающихся и исчезающих кварк-антикварковых пар. В этом кварковом море <a href="https://nplus1.ru/news/2022/08/18/intrinsic-charm-in-proton" rel="noreferrer noopener" target="_blank">могут</a> даже рождаться пары кварк-антикварк с массами больше массы самого нуклона. Все эти компоненты <a href="https://nplus1.ru/news/2019/03/15/sea-asymmetry" rel="noreferrer noopener" target="_blank">влияют</a> на свойства нуклонов. В частности, расчет массы протона <a href="https://nplus1.ru/news/2018/11/21/proton-dissecting" rel="noreferrer noopener" target="_blank">показывает</a>, что около 20 процентов его массы обеспечивается аномалиями, связанными с четырьмя кварками, которые не являются валентными (основными) для протона.</p></div>
# <div class="n1_material text-18"><p class="mb-6">В новой работе Коу Вэй (Wei Kou) и Чэнь Сюйжун (Xurong Chen) из Института Современной Физики Китайской академии наук рассчитали вклад странного кварка в массу протона на основе данных экспериментов J/ψ — 007 и GlueX. Для этого физики анализировали полученную в этих экспериментах зависимость дифференциального сечения припорогового процесса фоторождения векторного J/ψ мезона. Этот процесс можно использовать для получения гравитационного форм-фактора протона, который определяет распределение массы в нем.</p></div>
# <basegallerymain :gid="69814"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">В результате ученые определили массовый сигма-член, соответствующий странному кварку. Он оказался равен 455,62 ± 64,60 мегаэлектронвольта при аппроксимации экспериментальных данных экспоненциальной функцией или 337,74 ± 106,79 мегаэлектронвольта при использовании дипольной аппроксимации. Статистическая значимость ненулевого результата составила 7,1 и 3,2 стандартных отклонений соответственно.</p></div>
# <basegallerymain :gid="69815"></basegallerymain>
# <div></div>
# <div class="n1_material text-18"><p class="mb-6">Полученные значения вклада странного кварка в массу протона значительно превосходят предыдущие теоретические оценки и достигают около 40 процентов. Ученые отмечают, что эти результаты получены в предположении наличия только трех ароматических кварков в протоне. Поэтому результаты исследования существенно зависят от достоверности и точности оценки параметров модели.</p></div>
# <div class="n1_material text-18"><p class="mb-6">Процесс припорогового фоторождения векторных мезонов не в первый раз используется для изучения особенностей распределения массы в протоне. Ранее при помощи этого метода ученые <a href="https://nplus1.ru/news/2021/05/15/proton-mass-radius" rel="noreferrer noopener" target="_blank">определили</a> массовый радиус протона.</p></div>
# </div>
# <div class="text-18">
# <app-tags-carousel>
# <template v-slot:default="slotProps">
# <a :class="slotProps.classesTag" href="https://nplus1.ru/search?tags=869">Физика</a>
# <a :class="slotProps.classesTag" href="https://nplus1.ru/search?tags=919">Загадки протона</a>
# </template>
# </app-tags-carousel>
# <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
# </div>
# </div>
# </div>
# <!--right sidebar-->
# <div class="block col-span-6 md:col-span-4 lg:col-span-3 mt-10">
# <div class="w-full" data-ref-sidebar=""></div>
# <!--
#         <a class="text-14 leading-21 group" href="#">
#           <p>
#             Human mobility at Tell Atchana (Alalakh), Hatay, Turkey during the 2nd millennium BC: Integration of
#             isotopic and genomic evidence
#           </p>
#           <div class="group-hover:text-main inline-flex items-center font-spectral text-main-gray">
#             <p class="mr-1">PLOS ONE, 30.06.2021</p>
#             <svg class="fill-current" width="11" height="11" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#                     fill="currentColor"></path>
#             </svg>
#           </div>
#         </a>
#         -->
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
# <!--tags-->
# <!--main image  -->
# <!--main-->
# <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0">
# <div class="flex flex-col">
# <div class="text-34 md:text-42 xl:text-52 break-words">
#           Сверхнедоверие
#         </div>
# <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Страшный суд для одного ученого и комнатной сверхпроводимости</p>
# <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
# <a class="underline whitespace-nowrap" href="/author/artem-moskin">Артем Моськин</a>
# </div>
# <div class="n1_material text-18" id="read-next-2">
# <p class="mb-6">7 ноября из Nature отозвали уже вторую статью американского физика Ранги Диаса — спустя всего девять месяцев после публикации. В этот раз инициаторами выступили соавторы ученого, которые посчитали, что статья о сверхпроводящем при комнатной температуре гидриде лютеция «неточно отражает происхождение исследуемых материалов, проведенные экспериментальные измерения и примененные протоколы обработки данных». Масса вопросов к работе было и у научного сообщества: после выхода статьи появились десятки препринтов, некоторые из которых позже были опубликованы и в рецензируемых журналах. Материаловеды и физики не могли воспроизвести результаты Диаса. Редакторы Nature, осознав свою ошибку, инициировали независимое внутреннее расследование, которое тоже подтвердило сомнения критиков. Почему редакция журнала второй раз наступила на те же грабли и что теперь ждет Рангу Диаса?</p>
# </div>
# <div class="mt-5 md:mt-6">
# <a class="inline-flex justify-center bg-main w-full py-4" href="https://nplus1.ru/material/2023/11/28/dias-irae">
# <span class="text-white text-22 md:text-24">Читать дальше</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="mb-15 md:mb-20">
# <div class="bg-gray-100 w-full" id="adfox_154408219501673625"></div>
# </section>
# <div class="mb-1 w-full overflow-hidden">
# <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
# <template v-slot:default="slotProps">
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                                'padding-left': slotProps.left + 'px'
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/893323/conversions/65df536d5ca07_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/893324/conversions/65df536d9f509_hl_cover_h-conversion-webp.webp">
# <img alt="«Галилео» нашел на Земле континенты и кислородную атмосферу" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/893324/conversions/65df536d9f509_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/29">
# <span class="group-hover:text-main transition-colors duration-75">29.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=880">
# <span class="group-hover:text-main transition-colors duration-75">
#             Астрономия
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/4">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           4.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/29/earth-as-exoplanet">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           «Галилео» нашел на Земле континенты и кислородную атмосферу</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Наша планета выступила как аналог землеподобных экзопланет</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/891405/conversions/65d94a6dda268_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/891406/conversions/65d94a6e36aaf_hl_cover_h-conversion-webp.webp">
# <img alt="Частный посадочный модуль IM-1 упал на бок при посадке на Луну" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/891406/conversions/65d94a6e36aaf_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/24">
# <span class="group-hover:text-main transition-colors duration-75">24.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=871">
# <span class="group-hover:text-main transition-colors duration-75">
#             Космонавтика
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/24/im-1-photos">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Частный посадочный модуль IM-1 упал на бок при посадке на Луну</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Однако вырабатывает энергию и поддерживает связь с Землей</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/888784/conversions/65ce9f7ead119_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/888785/conversions/65ce9f7f091bf_hl_cover_h-conversion-webp.webp">
# <img alt="В средневековой европейской ДНК нашли признаки предрасположенности к проказе" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/888785/conversions/65ce9f7f091bf_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/16">
# <span class="group-hover:text-main transition-colors duration-75">16.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=877">
# <span class="group-hover:text-main transition-colors duration-75">
#             Антропология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.8
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/16/pull-the-plug">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           В средневековой европейской ДНК нашли признаки предрасположенности к проказе</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Образцы добыли в Дании и Германии</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/893105/conversions/65df1c0d272a0_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/893106/conversions/65df1c0dafa29_hl_cover_h-conversion-webp.webp">
# <img alt="Кипячение удалило из жесткой воды более восьмидесяти процентов микропластика" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/893106/conversions/65df1c0dafa29_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/28">
# <span class="group-hover:text-main transition-colors duration-75">28.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=872">
# <span class="group-hover:text-main transition-colors duration-75">
#             Экология и климат
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/28/vi_vse_eshe_kipyatite">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Кипячение удалило из жесткой воды более восьмидесяти процентов микропластика</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             А из мягкой воды — только 25 процентов</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/888961/conversions/65cf3d3eb28d1_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/888962/conversions/65cf3d3fbde10_hl_cover_h-conversion-webp.webp">
# <img alt="Археологи уточнили возраст неандертальцев из пещеры Виндия" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/888962/conversions/65cf3d3fbde10_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/17">
# <span class="group-hover:text-main transition-colors duration-75">17.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=876">
# <span class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.1
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/17/vindija-cave">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Археологи уточнили возраст неандертальцев из пещеры Виндия</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Они жили между 52 и 44 тысячами лет назад</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/890515/conversions/65d56297e6d9f_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/890516/conversions/65d562982dcc0_hl_cover_h-conversion-webp.webp">
# <img alt="Орнитологи впервые сфотографировали неуловимую птицу из горных лесов Конго" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/890516/conversions/65d562982dcc0_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/21">
# <span class="group-hover:text-main transition-colors duration-75">21.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=874">
# <span class="group-hover:text-main transition-colors duration-75">
#             Зоология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/2">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           2.3
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/21/prionops-alberti">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           Орнитологи впервые сфотографировали неуловимую птицу из горных лесов Конго</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             В последний раз этот вид встречали почти 20 лет назад</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/892013/conversions/65dcaf944d892_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/892014/conversions/65dcaf9492074_hl_cover_h-conversion-webp.webp">
# <img alt="В Томске встретили черного снегиря" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/892014/conversions/65dcaf9492074_hl_cover_h-conversion-webp.webp"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2024/02/26">
# <span class="group-hover:text-main transition-colors duration-75">26.02.24</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=874">
# <span class="group-hover:text-main transition-colors duration-75">
#             Зоология
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/1">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           1.5
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2024/02/26/black-bullfinch">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
#           В Томске встретили черного снегиря</p>
# <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light transition-colors duration-75 group-hover:text-main">
#             Необычная окраска птицы, скорее всего, связана с мутацией</p>
# </a>
# </div>
# </div>
# </div>
# <div :style="{'width': constWidthHorizontalsCard + 'px',
#                               }" class="absolute left-0 mr-1 box-content">
# <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
# <div class="shrink-0 absolute inset-0 group bg-main">
# <picture>
# <source media="(max-width: 1023px)" srcset="https://minio.nplus1.ru/app-images/240931/conversions/630199238e8a1_hl_cover_v-conversion-webp.webp">
# <source media="(min-width: 1024px)" srcset="https://minio.nplus1.ru/app-images/240932/conversions/63019923b6e23_hl_cover_h-conversion-webp.webp">
# <img alt="Омикрон оказался самым устойчивым во внешней среде вариантом коронавируса" class="w-full h-full object-cover absolute inset-0 brightness-50" loading="lazy" src="https://minio.nplus1.ru/app-images/240932/conversions/63019923b6e23_hl_cover_h-conversion-webp.webp" style="background-color: #070504"/>
# </source></source></picture>
# </div>
# <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
# <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/news/2022/01/25">
# <span class="group-hover:text-main transition-colors duration-75">25.01.22</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=873">
# <span class="group-hover:text-main transition-colors duration-75">
#             Медицина
#             </span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="https://nplus1.ru/search?tags=766">
# <span class="group-hover:text-main transition-colors duration-75">Коронавирусные хроники</span>
# </a>
# <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group" href="/material/difficulty/3">
# <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
# <use xlink:href="#n1_star"></use>
# </svg>
# <span class="group-hover:text-main transition-colors duration-75">
#           3.3
#         </span>
# </a>
# </div>
# <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group" href="https://nplus1.ru/news/2022/01/25/coronavirus-survivial">
# <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light transition-colors duration-75 group-hover:text-main">
# ...
# <ul class="flex gap-3 text-gray-2">
# <li>
# <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tg"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_vk"></use>
# </svg>
# </a>
# </li>
# <li>
# <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_ok"></use>
# </svg>
# </a>
# </li>
# <li class="w-12">
# <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
# <svg class="w-12 h-12">
# <use xlink:href="#n1_tw"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <svg class="stroke-current" fill="none" height="16" id="n1_star" style="display:block;width:0;height:0" viewbox="3 3 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 5V17"></path>
# <path d="M6.75781 6.75781L15.2431 15.2431"></path>
# <path d="M17 11L5 11"></path>
# <path d="M15.2422 6.75781L6.75691 15.2431"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_person" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle cx="25" cy="25" r="24.5"></circle>
# <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z" stroke-miterlimit="10"></path>
# </svg>
# <svg fill="none" id="n1_tg" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_vk" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_ok" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg fill="none" id="n1_tw" style="display:block;width:0;height:0" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"></path>
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# </svg>
# <svg height="64px" id="n1_infinity" preserveaspectratio="xMidYMid" style="display:block;width:0;height:0" viewbox="0 0 100 100" width="64px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z" fill="none" stroke="#ffffff" stroke-dasharray="146.25568908691406 110.33323913574219" stroke-linecap="round" stroke-width="5" style="transform:scale(0.8);transform-origin:50px 50px">
# <animate attributename="stroke-dashoffset" dur="1.3157894736842106s" keytimes="0;1" repeatcount="indefinite" values="0;256.58892822265625"></animate>
# </path>
# </svg>
# <svg fill="none" id="n1_cross" style="display:block;width:0;height:0" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"></path>
# <path d="M13 1L1 13" stroke="#F9F9F9"></path>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewbox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z" fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" viewbox="0 0 61 61" xmlns="http://www.w3.org/2000/svg">
# <path class="fill-current" clip-rule="evenodd" d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z" fill-rule="evenodd"></path>
# <path class="fill-current" d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"></path>
# </svg>
# <svg class="stroke-current" fill="none" id="n1_circle_arrow" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <rect height="29" rx="14.5" transform="rotate(-180 29.5 29.5)" width="29" x="29.5" y="29.5"></rect>
# <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"></path>
# </svg>
# <svg fill="none" id="n1_circle_arrow_solid" style="display:block;width:0;height:0" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <mask id="path-1-inside-1_2694_77554">
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill-rule="evenodd"></path>
# </mask>
# <path clip-rule="evenodd" d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z" fill="#fff" fill-rule="evenodd"></path>
# <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z" fill="#fff" mask="url(#path-1-inside-1_2694_77554)"></path>
# </svg>
# <svg fill="none" id="n1_play" style="display:block;width:0;height:0;" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
# <circle class="stroke-current" cx="25" cy="25" r="24.5"></circle>
# <path class="stroke-current" d="M18 35V15L36 25L18 35Z"></path>
# </svg>
# <svg fill="none" id="n1_pupa" style="display:block;width:0;height:0;" viewbox="0 0 24 23" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z" fill="#32363A" fill-rule="evenodd"></path>
# </svg>
# <svg fill="none" id="n1_burger" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <line stroke="#32363A" x2="30" y1="6.5" y2="6.5"></line>
# <line stroke="#32363A" x2="30" y1="23.5" y2="23.5"></line>
# <line stroke="#32363A" x2="30" y1="15" y2="15"></line>
# </svg>
# <svg fill="none" id="n1_cross_menu" style="display:block;width:0;height:0;" viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 4L26 26" stroke="#32363A"></path>
# <path d="M26 4L4 26" stroke="#32363A"></path>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" version="1.1" viewbox="0 0 752 752" xmlns="http://www.w3.org/2000/svg">
# <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"></path>
# </svg>
# <svg id="n1_specials_star" style="display:block;width:0;height:0;fill:none;stroke:white" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"></path>
# </svg>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=031caa46d918adf54bd0f432e1a877eb"></script>
# <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;"/>
# <img alt="" src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
# </body>
# </html>

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим повнимательнее на это:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="#f26e40" name="msapplication-TileColor"/>,
#  <meta content="#ffffff" name="theme-color"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>,
#  <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="description"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:site_name"/>,
#  <meta content="Физики раскрыли странность протона" property="og:title"/>,
#  <meta content="https://minio.nplus1.ru/app-images/894593/65e3641179ef8_cover_share.jpg" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2024/03/02/proton-strangeness" property="og:url"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" property="og:description"/>,
#  <meta content="article" property="og:type"/>,
#  <meta content="2024-03-02" itemprop="datePublished"/>,
#  <meta content="2024-03-02" itemprop="datePublished"/>,
#  <meta content="Дмитрий Рудик" name="mediator_author"/>,
#  <meta content="Дмитрий Рудик" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Физики раскрыли странность протона" name="twitter:title"/>,
#  <meta content="N + 1 — главное издание о науке, технике и технологиях" name="twitter:description"/>,
#  <meta content="https://minio.nplus1.ru/app-images/894593/65e3641179ef8_cover_share.jpg" name="twitter:image"/>]

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой и заголовком. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Дмитрий Рудик" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Дмитрий Рудик" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Дмитрий Рудик'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find_all('meta', {'name' : 'author'})[0].get('content')
author
# Out:
# 'Дмитрий Рудик'

# %% [markdown]
# Аналогичным образом извлечем дату и заголовок.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')

# %%
title
# Out:
# 'Физики раскрыли странность протона'

# %% [markdown]
# Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет название новости и всю необходимую информацию (дата, автор и т.п.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Возвращает кортеж с url0, date, author, title.
    Параметры:

    url0 - ссылка на новость (строка).
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'html')

    try:
        author = soup0.find_all('meta', {'name' : 'author'})[0].get('content')
    except IndexError:
        author = None
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].get('content')
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].get('content')

    return url0, date, author, title

# %%
help(GetNews)
# Out:
# Help on function GetNews in module __main__:
#
# GetNews(url0)
#     Возвращает кортеж с url0, date, author, title.
#     Параметры:
#
#     url0 - ссылка на новость (строка).

# %% [markdown]
# Уфф. Осталось применить нашу функцию в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще и автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится (сейчас это не очень важно, но особенно актуально будет, если рассматривать встраивание в браузер с Selenium). Приступим.

# %%
from time import sleep

# %%
len(urls)
# Out:
# 71

# %%
news = [] # это будет список из кортежей, в которых будут храниться данные по каждой новости

for link in urls[10:25]:
    print(link)
    res = GetNews(link)
    news.append(res)

    sleep(3) # задержка в 3 секунды
# Out:
# https://nplus1.ru/news/2024/03/01/im-1-sleep
# https://nplus1.ru/news/2024/03/01/w-1-reentry
# https://nplus1.ru/news/2024/03/01/4c-37-11
# https://nplus1.ru/news/2024/03/01/im-1-ilo
# https://nplus1.ru/news/2024/03/01/posttraumatic-epilepsy-dementia
# https://nplus1.ru/news/2024/03/01/problem-solving-bird
# https://nplus1.ru/news/2024/03/01/suboptimal-asthma-care-ghg
# https://nplus1.ru/news/2024/03/01/man-eating-wolves
# https://nplus1.ru/news/2024/03/01/brokeback-whale
# https://nplus1.ru/news/2024/03/01/predators-in-changing-climate
# https://nplus1.ru/news/2024/03/01/trawniki-from-treblinka
# https://nplus1.ru/news/2024/03/01/simple-vs-radical-hysterectomy
# https://nplus1.ru/news/2024/03/01/dimorphos-shape
# https://nplus1.ru/news/2024/03/01/dont-pack-to-go
# https://nplus1.ru/news/2024/02/29/hl-taurus

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %%
news[0]
# Out:
# ('https://nplus1.ru/news/2024/03/01/im-1-sleep',
#  '2024-03-01',
#  'Александр Войтюк',
#  'Частный посадочный модуль IM-1 уснул на\xa0Луне')

# %% [markdown]
# Импортируем `pandas` и создадим датафрейм из списка кортежей:

# %%
import pandas as pd

# %%
df = pd.DataFrame(news)

# %%
df.head(2)
# Out:
#                                             link        date  \
# 0   https://nplus1.ru/news/2024/03/01/im-1-sleep  2024-03-01
# 1  https://nplus1.ru/news/2024/03/01/w-1-reentry  2024-03-01
#
#              author                                              title
# 0  Александр Войтюк       Частный посадочный модуль IM-1 уснул на Луне
# 1  Александр Войтюк  Varda Space показала видео спуска в атмосфере ...

# %% [markdown]
# Переименуем столбцы в базе.

# %%
df.columns = ['link', 'date', 'author', 'title']

# %%
df
# Out:
#                                                  link        date  \
# 0        https://nplus1.ru/news/2024/03/01/im-1-sleep  2024-03-01
# 1       https://nplus1.ru/news/2024/03/01/w-1-reentry  2024-03-01
# 2          https://nplus1.ru/news/2024/03/01/4c-37-11  2024-03-01
# 3          https://nplus1.ru/news/2024/03/01/im-1-ilo  2024-03-01
# 4   https://nplus1.ru/news/2024/03/01/posttraumati...  2024-03-01
# 5   https://nplus1.ru/news/2024/03/01/problem-solv...  2024-03-01
# 6   https://nplus1.ru/news/2024/03/01/suboptimal-a...  2024-03-01
# 7   https://nplus1.ru/news/2024/03/01/man-eating-w...  2024-03-01
# 8   https://nplus1.ru/news/2024/03/01/brokeback-whale  2024-03-01
# 9   https://nplus1.ru/news/2024/03/01/predators-in...  2024-03-01
# 10  https://nplus1.ru/news/2024/03/01/trawniki-fro...  2024-03-01
# 11  https://nplus1.ru/news/2024/03/01/simple-vs-ra...  2024-03-01
# 12  https://nplus1.ru/news/2024/03/01/dimorphos-shape  2024-03-01
# 13  https://nplus1.ru/news/2024/03/01/dont-pack-to-go  2024-03-01
# 14        https://nplus1.ru/news/2024/02/29/hl-taurus  2024-02-29
#
#               author                                              title
# 0   Александр Войтюк       Частный посадочный модуль IM-1 уснул на Луне
# 1   Александр Войтюк  Varda Space показала видео спуска в атмосфере ...
# 2   Александр Войтюк  Астрономы отыскали самую тяжелую пару сверхмас...
# 3   Александр Войтюк  Лунный модуль IM-1 сфотографировал свою отлома...
# 4      Слава Гоменюк  Эпилепсия после травмы головы повысила риск ра...
# 5   Катерина Петрова  Способность птиц решать головоломки с едой свя...
# 6      Марина Попова  Недостаточная забота о здоровье астматиков при...
# 7    Михаил Подрезов  Изотопы из шерсти волка-людоеда из Турку расск...
# 8     Сергей Коленов  Горбатые киты впервые спарились на глазах у лю...
# 9      Марина Попова  Гибкость в выборе жертв подвела хищных рыб в а...
# 10   Михаил Подрезов           В Треблинке нашли могилы лагерной охраны
# 11     Слава Гоменюк  Гинекологи разрешили удалять только матку с ше...
# 12  Александр Войтюк  Моделирование подтвердило изменение формы Димо...
# 13        Олег Лищук  США прекратили использовать ПФАС в пищевых упа...
# 14  Александр Войтюк  ALMA взвесила водяной пар в протопланетном дис...

# %% [markdown]
# Всё! Сохраняем датафрейм в файл. Для разнообразия сохраним в Excel:

# %%
df.to_excel('nplus-news.xlsx', index=False)

# %% [markdown]
# Дело сделано! Мы молодцы!

# %% [markdown]
# ### Практика
#
# В качестве ещё одного практического примера, на котором можно потренироваться, а заодно и отточить свои навыки парсинга данных, — рассмотрим обработку сайта с большим каталогом книг на продажу [(ссылка)](http://books.toscrape.com/catalogue/page-1.html). Сайт этот, кстати, представляет собой специальный тренировочный портал для практики веб-скрейпинга на данных близких к реальным, а значит особых затруднений в процессе его обработки у нас возникнуть не должно.
#
# Сам процесс веб-скрейпинга и парсинга давайте будем осуществлять с минимумом комментариев и пояснений, поскольку глобально мы лишь повторяем то, что уже проделали чуть ранее, — последуем тут старинному принципу: "Нет времени обсуждать — пишем код!"
#
# Итак, поехали!

# %%
url = 'http://books.toscrape.com/catalogue/page-1.html'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content[:1000]
# Out:
# b'\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:30" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="../static/oscar/fav'

# %%
tree = BeautifulSoup(response.content, 'html.parser')

# %%
tree.html.head.title.text.strip()
# Out:
# 'All products | Books to Scrape - Sandbox'

# %%
books = tree.find_all('article', {'class' : 'product_pod'})
books[5]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="the-requiem-red_995/index.html"><img alt="The Requiem Red" class="thumbnail" src="../media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a></h3>
# <div class="product_price">
# <p class="price_color">£22.65</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
books[0].find('p', {'class': 'price_color'}).text
# Out:
# '£51.77'

# %%
books[0].a.get('href')
# Out:
# 'a-light-in-the-attic_1000/index.html'

# %%
books[0].h3.a.get('title')
# Out:
# 'A Light in the Attic'

# %%
books[7].p.get('class')[1]
# Out:
# 'Three'

# %%
def get_page(p):
    url = f'http://books.toscrape.com/catalogue/page-{p}.html'
    response = requests.get(url)
    tree = BeautifulSoup(response.content, 'html.parser')
    books = tree.find_all('article', {'class' : 'product_pod'})

    info = []

    for book in books:
        info.append({'price': book.find('p', {'class': 'price_color'}).text,
                     'href': book.h3.a.get('href'),
                     'title': book.h3.a.get('title'),
                    'rating': book.p.get('class')[1]})

    return info

# %%
from tqdm import tqdm

# %%
infa = []

for p in tqdm(range(1,51)):
    try:
        infa.extend(get_page(p))
        sleep(5)
    except:
        print(p)
# Out:
# 100%|██████████| 50/50 [04:13<00:00,  5.07s/it]

# %%
df = pd.DataFrame(infa)
print(df.shape)
df.head()
# Out:
# (1000, 4)
#     price                                               href  \
# 0  £51.77               a-light-in-the-attic_1000/index.html
# 1  £53.74                  tipping-the-velvet_999/index.html
# 2  £50.10                          soumission_998/index.html
# 3  £47.82                       sharp-objects_997/index.html
# 4  £54.23  sapiens-a-brief-history-of-humankind_996/index...
#
#                                    title rating
# 0                   A Light in the Attic  Three
# 1                     Tipping the Velvet    One
# 2                             Soumission    One
# 3                          Sharp Objects   Four
# 4  Sapiens: A Brief History of Humankind   Five

# %%
df.to_csv('books_parsed.csv', index=False)

# %%
df.to_excel('books_parsed.xlsx', index=False)

# %% [markdown]
# Ну что, всё получилось, всё понятно?
#
# Попробуйте теперь самостоятельно!

# %% [markdown]
# ### Задания для самостоятельного решения (парсинг сайта)
#
# По аналогии с примером выше вам предстоит собрать данные с сайта https://quotes.toscrape.com/.
#
# 1) Распарсив html-страницу с цитатами, извлеките с сайта саму цитату, автора цитаты, а также все теги, связанные с этой цитатой.
#
# 2) Напишите программу, где пользователь вводит тег, а ему выводятся все цитаты, у которых есть такой тег (например, 'truth').

# %%
# your code here

# %% [markdown]
# ## Раздел 2. Работа с API

# %% [markdown]
# До этого мы с вами собирали данные вручную, обращаясь к html-страницам, размеченным для отображения в браузере. Но данные также можно собирать и через API — application program interface.
#
# Обычный интерфейс — это способ взаимодействия человека с программой, а API — одной программы с другой, например, вашего скрипта на Python — с удалённым веб-сервером.
#
# Именно обсуждению такого прекрасного инструмента как API — а также всего, что с ним связано, — будет посвящен данный раздел семинара.

# %% [markdown]
# ### Язык XML
#
# Для хранения веб-страниц, которые читают люди, используется язык HTML. Для хранения произвольных структурированных данных, которыми обмениваются между собой программы, используются другие языки — в частности, язык XML, похожий на HTML. Точнее, XML — это, на самом деле, даже не язык, а скорее метаязык — то есть способ описания языков. В отличие от HTML, набор тегов в XML-документе может быть произвольным (и определяется разработчиком конкретного диалекта XML). Например, если бы мы хотели описать в виде XML некоторую студенческую группу, это могло бы выглядеть так:
#
# ```xml
# <group>
#     <number>134</number>
#     <student>
#         <firstname>Виталий</firstname>
#         <lastname>Иванов</lastname>
#     </student>
#     <student>
#         <firstname>Мария</firstname>
#         <lastname>Петрова</lastname>
#     </student>
# </group>
# ```

# %% [markdown]
# Для обработки XML-файлов можно использовать тот же пакет *Beautiful Soup*, который мы уже использовали для работы с HTML. Единственное различие — нужно указать дополнительный параметр `features="xml"` при вызове функции `BeautifulSoup` — чтобы он не искал в документе HTML-теги.

# %%
group = """<group>
<number>134</number>
<student>
<firstname>Виталий</firstname>
<lastname>Иванов</lastname>
</student>
<student>
<firstname>Мария</firstname>
<lastname>Петрова</lastname>
</student>
</group>"""

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)

# %%
obj = BeautifulSoup(group, features="lxml")
print(obj.prettify())
# Out:
# <html>
#  <body>
#   <group>
#    <number>
#     134
#    </number>
#    <student>
#     <firstname>
#      Виталий
#     </firstname>
#     <lastname>
#      Иванов
#     </lastname>
#    </student>
#    <student>
#     <firstname>
#      Мария
#     </firstname>
#     <lastname>
#      Петрова
#     </lastname>
#    </student>
#   </group>
#  </body>
# </html>

# %% [markdown]
# Номер группы можно найти, например, вот так — для каждого объекта через точку указываем его атрибут, в который надо спуститься.

# %%
obj.group.number.text # последний атрибут текст, точно также как делали в html
# Out:
# '134'

# %% [markdown]
# Но это работает только тогда, когда тэг уникальный. В других случаях, парсер всегда будет попадать в первый child-тэг, который он встретил по пути вниз.

# %%
obj.group.student.lastname.text # до Петровой так не добраться
# Out:
# 'Иванов'

# %% [markdown]
# Перечислить всех студентов можно с помощью цикла (похожая структура у нас была и в обработке html).

# %%
for student in obj.group.find_all('student'):
    print(student.lastname.text, student.firstname.text)
# Out:
# Иванов Виталий
# Петрова Мария

# %% [markdown]
# По сути, главное отличие xml от html, что работать вы будете не со стандартизированными структурами. Поэтому перед работой придется поиграть в детективов — запросить данные и внимательно изучить расположение узлов, чтобы понять, какие тэги вас интересуют.

# %% [markdown]
# ### Язык JSON
#
# Другой популярный формат, в котором клиент может отдать вам данные — это язык json. JSON расшифровывается как JavaScript Object Notation и изначально возник как подмножество языка JavaScript, используемое для описания объектов. Впрочем, впоследствии он начал использоваться и в других языках программирования, включая, конечно, Python.
#
# Различные API могут поддерживать либо XML, либо JSON, либо и то, и другое одновременно, так что нам полезно будет научиться работать с обоими типами данных.

# %% [markdown]
# В целом, JSON очень похож на описание объекта в Python, и смысл квадратных и фигурных скобок здесь абсолютно такой же. Правда, есть и отличия: например, в Python одинарные и двойные кавычки ничем не отличаются, а в JSON можно использовать только двойные.
#
# Полученный нами JSON-файл, как правило, представляет собой словарь, значения которого — строки или числа, а также списки или словари, значения которых в свою очередь также могут быть строками, числами, списками, словарями и т.д. Таким образом получается довольно сложная, ветвистая структура данных.
#
# Впрочем, здесь очень важно сделать  ремарку, что тот факт, что перед нами сложная структура данных, видим только мы, но не программа — с точки зрения Python, j.text это просто какая-то строка. Однако в модуле requests присутствует специальный метод, позволяющий сразу выдать питоновский объект (словарь или список), если результат запроса возвращён в формате JSON. Так что нам в любом случае не придётся использовать какие-либо дополнительные библиотеки и сильно усложнять себе жизнь.

# %% [markdown]
# Подводя итог, хочется еще раз резюмировать, что основные преимущества JSON заключаются в том, что мы получаем готовый объект Python и нет необходимости использовать какие-то сторонние библиотеки для того, чтобы с ним работать. Недостатком является то же самое: зачастую поиск информации в XML-файле может проводиться более эффективно, чем в JSON.

# %% [markdown]
# ### API для веб-сайтов
#
# В рамках этого блока ваш семинарист осуществит смертельный номер: вы обсудите понятия API-ключа, протоколов API; изучите документацию по API для широкоизвестного российского портала; а также осуществите live-coding по сбору данных с этого ресурса автоматизированным образом.
#
# В общем, будет интересно! Не переключайтесь! :)
